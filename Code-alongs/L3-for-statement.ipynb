# %% [markdown]
# # for loop

# %%
for i in range(5):
    print(i, end=" ")
# Out:
# 0 1 2 3 4

# %%
my_sum = 0

for i in range(10):
    my_sum += i

print(f"{my_sum=}")
# Out:
# my_sum=45

# %% [markdown]
# ## loop through a list

# %%
cute_animals = ["rabbit", "pig", "cat", "dog"]

for animal in cute_animals:
    print(f"{animal}s are cute")
# Out:
# rabbits are cute
# pigs are cute
# cats are cute
# dogs are cute

# %% [markdown]
# ## random module

# %%
import random as rnd

numb_six = 0
numb_rolls = 10

for i in range(numb_rolls):
    dice = rnd.randint(1,6)
    if dice == 6:
        numb_six += 1

print(f"{numb_six=}")
print(f"proportion of sixes {numb_six/numb_rolls}")
# Out:
# numb_six=3
# proportion of sixes 0.3

# %%
import math

for year in range(10000):
    past_cons = .791*math.exp(.0526*year)
    if past_cons >= 15:
        print(f"år {year+1960} är pastakonsuptionen 15/person per år")
        break
# Out:
# år 2016 är pastakonsuptionen 15/person per år

# %%
import matplotlib.pyplot as plt

pasta_per_year = []

for year in range(140):
    past_cons = .791*math.exp(.0526*year)
    pasta_per_year.append(past_cons)

plt.plot(range(1960,2100), pasta_per_year)
plt.xlabel("År")
plt.ylabel("pastakonsumption i kg")
plt.title("Pastakonsumtion/kg per person per år från 1960")
# Out:
# Text(0.5, 1.0, 'Pastakonsumtion/kg per person per år från 1960')

# %% [markdown]
# ## nested loops
#
# - a loop in a loop

# %%
for row in range (1,4):
    for col in range(1,4):
        print(f"({row},{col})", end="")
    print()
# Out:
# (1,1)(1,2)(1,3)
# (2,1)(2,2)(2,3)
# (3,1)(3,2)(3,3)
